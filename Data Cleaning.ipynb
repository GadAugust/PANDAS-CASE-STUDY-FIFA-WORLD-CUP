# %% [markdown]
#  # TASKS: Data Cleaning
#
# 1. Convert the date column to datetime datatype.
# 2. Standardize the column names.
# 3. Handle missing values appropriately, if they exist. Justify your chosen method for
# handling the missing values.
# 4. Are there duplicates in the dataset? If yes, record the number of duplicates and handle
# appropriately.
# 5. Handle outliers in the dataset, if they exist. Justify your method of handling the
# outliers.

# %%
# import libraries
import pandas as pd

# %%
#install pyarrow
# !pip install pyarrow
# Out:
# Requirement already satisfied: pyarrow in /usr/local/python/3.10.13/lib/python3.10/site-packages (15.0.0)
# Requirement already satisfied: numpy<2,>=1.16.6 in /home/codespace/.local/lib/python3.10/site-packages (from pyarrow) (1.26.4)

# %%
# loading my dataset

cup_df = pd.read_csv('world_cup_matches.csv')

# %%
# Making a copy of it for refrence
df = cup_df.copy()

# %% [markdown]
# # 1. Convert the date column to datetime datatype.

# %%
# changing date  
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              900 non-null    int64
#  1   Year            900 non-null    int64
#  2   Date            900 non-null    datetime64[ns]
#  3   Stage           900 non-null    object
#  4   Home Team       900 non-null    object
#  5   Home Goals      900 non-null    int64
#  6   Away Goals      900 non-null    int64
#  7   Away Team       900 non-null    object
#  8   Win Conditions  62 non-null     object
#  9   Host Team       900 non-null    bool
# dtypes: bool(1), datetime64[ns](1), int64(4), object(4)
# memory usage: 64.3+ KB

# %%
2. Standardize the column names.

# %%
#change column to lowercase

df.columns = df.columns.str.lower()

# %%
df.columns
# Out:
# Index(['id', 'year', 'date', 'stage', 'home team', 'home goals', 'away goals',
#        'away team', 'win conditions', 'host team'],
#       dtype='object')

# %%
# replace whitespace
df.columns = df.columns.str.replace(' ', '_')

# %%
df.columns
# Out:
# Index(['id', 'year', 'date', 'stage', 'home_team', 'home_goals', 'away_goals',
#        'away_team', 'win_conditions', 'host_team'],
#       dtype='object')

# %%
df
# Out:
#       id  year       date           stage      home_team  home_goals  \
# 0      1  1930 1930-07-13     Group stage         France           4
# 1      2  1930 1930-07-13     Group stage  United States           3
# 2      3  1930 1930-07-14     Group stage     Yugoslavia           2
# 3      4  1930 1930-07-14     Group stage        Romania           3
# 4      5  1930 1930-07-15     Group stage      Argentina           1
# ..   ...   ...        ...             ...            ...         ...
# 895  896  2018 2018-07-07  Quarter-finals         Russia           2
# 896  897  2018 2018-07-10     Semi-finals         France           1
# 897  898  2018 2018-07-11     Semi-finals        Croatia           2
# 898  899  2018 2018-07-14     Third place        Belgium           2
# 899  900  2018 2018-07-15           Final         France           4
#
#      away_goals away_team                    win_conditions  host_team
# 0             1    Mexico                               NaN      False
# 1             0   Belgium                               NaN      False
# 2             1    Brazil                               NaN      False
# 3             1      Peru                               NaN      False
# 4             0    France                               NaN      False
# ..          ...       ...                               ...        ...
# 895           2   Croatia  Croatia win on penalties (3 - 4)       True
# 896           0   Belgium                               NaN      False
# 897           1   England                        Extra time      False
# 898           0   England                               NaN      False
# 899           2   Croatia                               NaN      False
#
# [900 rows x 10 columns]

# %% [markdown]
# 3. Handle missing values appropriately, if they exist. Justify your chosen method for handling the missing values.

# %%
# Handling missing conditions
df['win_conditions'] = df['win_conditions'].fillna("Normal Time")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              900 non-null    int64
#  1   year            900 non-null    int64
#  2   date            900 non-null    datetime64[ns]
#  3   stage           900 non-null    object
#  4   home_team       900 non-null    object
#  5   home_goals      900 non-null    int64
#  6   away_goals      900 non-null    int64
#  7   away_team       900 non-null    object
#  8   win_conditions  900 non-null    object
#  9   host_team       900 non-null    bool
# dtypes: bool(1), datetime64[ns](1), int64(4), object(4)
# memory usage: 64.3+ KB

# %% [markdown]
# NB: You dont handle missing values alone, but with the business team,that has the domain knowledge, collaboration is key!

# %% [markdown]
# 4. Are there duplicates in the dataset? If yes, record the number of duplicates and handle appropriately.

# %%
#checking for duplicates
# no duplicates in our dataset
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 895    False
# 896    False
# 897    False
# 898    False
# 899    False
# Length: 900, dtype: bool

# %% [markdown]
# 5. Handle outliers in the dataset, if they exist. Justify your method of handling the outliers.

# %%
## Handling outliers
df.describe()
# Out:
#                id         year                 date  home_goals  away_goals
# count  900.000000   900.000000                  900  900.000000  900.000000
# mean   450.500000  1986.915556  1987-05-20 16:24:00    1.792222    1.038889
# min      1.000000  1930.000000  1930-07-13 00:00:00    0.000000    0.000000
# 25%    225.750000  1970.000000  1970-06-14 00:00:00    1.000000    0.000000
# 50%    450.500000  1990.000000  1990-06-23 12:00:00    2.000000    1.000000
# 75%    675.250000  2006.000000  2006-06-19 00:00:00    3.000000    2.000000
# max    900.000000  2018.000000  2018-07-15 00:00:00   10.000000    7.000000
# std    259.951919    23.150270                  NaN    1.593279    1.081567

# %%
## NB: Handling outliers in a dataset you need to collaborate with the business to actually know what happened 
## To know if a particular outlier occured or happend

# %%
#we start by subsetting dataframe 
condition = df['home_goals'] > 6
df[condition]
# Out:
#       id  year       date              stage   home_team  home_goals  \
# 24    25  1934 1934-05-27        Round of 16       Italy           7
# 46    47  1938 1938-06-12     Quarter-finals      Sweden           8
# 66    67  1950 1950-07-02        First round     Uruguay           8
# 70    71  1950 1950-07-09        Final round      Brazil           7
# 81    82  1954 1954-06-17        Group stage     Hungary           9
# 83    84  1954 1954-06-19        Group stage     Uruguay           7
# 87    88  1954 1954-06-20        Group stage     Hungary           8
# 88    89  1954 1954-06-20        Group stage      Turkey           7
# 91    92  1954 1954-06-23        Group stage     Germany           7
# 105  106  1958 1958-06-08        Group stage      France           7
# 243  244  1974 1974-06-18  First group stage  Yugoslavia           9
# 312  313  1982 1982-06-15  First group stage     Hungary          10
# 583  584  2002 2002-06-01        Group stage     Germany           8
# 737  738  2010 2010-06-21        Group stage    Portugal           7
#
#      away_goals      away_team win_conditions  host_team
# 24            1  United States    Normal Time       True
# 46            0           Cuba    Normal Time      False
# 66            0        Bolivia    Normal Time      False
# 70            1         Sweden    Normal Time       True
# 81            0    South Korea    Normal Time      False
# 83            0       Scotland    Normal Time      False
# 87            3        Germany    Normal Time      False
# 88            0    South Korea    Normal Time      False
# 91            2         Turkey    Normal Time      False
# 105           3       Paraguay    Normal Time      False
# 243           0       DR Congo    Normal Time      False
# 312           1    El Salvador    Normal Time      False
# 583           0   Saudi Arabia    Normal Time      False
# 737           0    North Korea    Normal Time      False

# %%
# for example Hungary and El salvador actually true
## if i want to see the average goal in a tournament then i have to remove the outliers, 
## they will highly impart my average because they are highly rarely
## we would need to remove these roles as it will impart the average when reporting to the management

# %% [markdown]
# 5. Handle outliers in the dataset, if they exist. Justify your method of handling the outliers.
#
# One approach is to remove outliers from the dataset. This can be done by filtering out data points that fall outside a certain range based on Z-score or IQR.

# %%
condition = df['home_goals'] > 6
df[condition]
# Out:
#       id  year       date              stage   home_team  home_goals  \
# 24    25  1934 1934-05-27        Round of 16       Italy           7
# 46    47  1938 1938-06-12     Quarter-finals      Sweden           8
# 66    67  1950 1950-07-02        First round     Uruguay           8
# 70    71  1950 1950-07-09        Final round      Brazil           7
# 81    82  1954 1954-06-17        Group stage     Hungary           9
# 83    84  1954 1954-06-19        Group stage     Uruguay           7
# 87    88  1954 1954-06-20        Group stage     Hungary           8
# 88    89  1954 1954-06-20        Group stage      Turkey           7
# 91    92  1954 1954-06-23        Group stage     Germany           7
# 105  106  1958 1958-06-08        Group stage      France           7
# 243  244  1974 1974-06-18  First group stage  Yugoslavia           9
# 312  313  1982 1982-06-15  First group stage     Hungary          10
# 583  584  2002 2002-06-01        Group stage     Germany           8
# 737  738  2010 2010-06-21        Group stage    Portugal           7
#
#      away_goals      away_team win_conditions  host_team
# 24            1  United States    Normal Time       True
# 46            0           Cuba    Normal Time      False
# 66            0        Bolivia    Normal Time      False
# 70            1         Sweden    Normal Time       True
# 81            0    South Korea    Normal Time      False
# 83            0       Scotland    Normal Time      False
# 87            3        Germany    Normal Time      False
# 88            0    South Korea    Normal Time      False
# 91            2         Turkey    Normal Time      False
# 105           3       Paraguay    Normal Time      False
# 243           0       DR Congo    Normal Time      False
# 312           1    El Salvador    Normal Time      False
# 583           0   Saudi Arabia    Normal Time      False
# 737           0    North Korea    Normal Time      False
